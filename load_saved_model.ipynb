# %%
#loading saved state_dict linear model.

import torch
import torch.nn as nn
import pandas as pd
import seaborn as sns

class LinearRegressionTorch(nn.Module):
    def __init__(self, input_size, output_size):
        super(LinearRegressionTorch, self).__init__()
        self.linear = nn.Linear(input_size, output_size)

    def forward(self, x):
        return self.linear(x)
        
input_size = 1
output_size = 1

model = LinearRegressionTorch(input_size, output_size)
model.load_state_dict(torch.load('linear_regression_model.pth'))
# Out:
# <All keys matched successfully>

# %%
cars_file = 'https://gist.githubusercontent.com/noamross/e5d3e859aa0c794be10b/raw/b999fb4425b54c63cab088c0ce2c0d6ce961a563/cars.csv'
cars = pd.read_csv(cars_file)

# %%
sns.scatterplot(x=cars.wt, y=cars.mpg)
sns.lineplot(x=cars.wt, y=model(torch.tensor(cars.wt.values.tolist()).reshape(-1,1)).data.numpy().reshape(-1), color='red')
# Out:
# <Axes: xlabel='wt', ylabel='mpg'>
